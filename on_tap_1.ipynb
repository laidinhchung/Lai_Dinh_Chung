# %%
class SinhVien:
    def __init__(self, maSV, hoTen, lop, ):
        self.maSV = maSV
        self.hoTen = hoTen
        self.lop = lop

    def infor(self):
        return f"{self.maSV} {self.hoTen} {self.lop} "

    def svk18a3(SinhVien):
        def __init__(self, maSV, hoTen, lop):
            super().__init__(maSV, hoTen, lop)

        def infor(self):
            return f"{self.maSV} {self.hoTen} {self.lop} K18A3"
